# %% [markdown]
# # Model Evaluation Notebook
#
# Detailed error analysis, confusion matrix plotting, and visualizing misclassified examples.

# %%
import sys
sys.path.append('..')
from src.inference import predict_single_image

# ... Evaluation Code Here ...
